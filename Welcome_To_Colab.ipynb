# %% [markdown]
# <a href="https://colab.research.google.com/github/thanvanth46/flipcart-sales-dataset/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/flipkart_sales (1).csv")
df
# Out:
#      Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   object
#  1   Product Name       1000 non-null   object
#  2   Category           1000 non-null   object
#  3   Price (INR)        1000 non-null   float64
#  4   Quantity Sold      1000 non-null   int64
#  5   Total Sales (INR)  1000 non-null   float64
#  6   Order Date         1000 non-null   object
#  7   Payment Method     1000 non-null   object
#  8   Customer Rating    1000 non-null   float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 70.4+ KB

# %%
print(df.shape)
# Out:
# (1000, 9)

# %%
print(df.columns)
# Out:
# Index(['Order ID', 'Product Name', 'Category', 'Price (INR)', 'Quantity Sold',
#        'Total Sales (INR)', 'Order Date', 'Payment Method', 'Customer Rating'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Order ID             0
# Product Name         0
# Category             0
# Price (INR)          0
# Quantity Sold        0
# Total Sales (INR)    0
# Order Date           0
# Payment Method       0
# Customer Rating      0
# dtype: int64

# %%
df=df.dropna()

# %%
df.loc[3-1,'Category']
# Out:
# 'Beauty'

# %%
df.loc[3:7,'Product Name']
# Out:
# 3       Smartwatch
# 4     Cookware Set
# 5    Mixer Grinder
# 6         Sneakers
# 7       Table Lamp
# Name: Product Name, dtype: object

# %%
df.loc[[1,3,4,5,8,2],['Product Name','Category','Price (INR)','Quantity Sold','Total Sales (INR)','Order Date']]
# Out:
#     Product Name        Category  Price (INR)  Quantity Sold  \
# 1          Jeans        Clothing     12755.85              4
# 3     Smartwatch     Electronics     32657.81              1
# 4   Cookware Set  Home & Kitchen     26590.08              3
# 5  Mixer Grinder  Home & Kitchen     10475.03              2
# 8         Jacket        Clothing      1987.39              2
# 2     Face Cream          Beauty     11092.19              4
#
#    Total Sales (INR)  Order Date
# 1           51023.40  2024-12-18
# 3           32657.81  2024-11-08
# 4           79770.24  2024-12-27
# 5           20950.06  2024-10-22
# 8            3974.78  2025-01-18
# 2           44368.76  2024-05-18

# %%
cate=df[df['Category']=='Clothing']
cate['Category'].unique()
# Out:
# array(['Clothing'], dtype=object)

# %%
cate['Category'].unique()
# Out:
# array(['Clothing'], dtype=object)

# %%
cate
# Out:
#      Order ID Product Name  Category  Price (INR)  Quantity Sold  \
# 1    ORD00002        Jeans  Clothing     12755.85              4
# 6    ORD00007     Sneakers  Clothing     38647.72              3
# 8    ORD00009       Jacket  Clothing      1987.39              2
# 19   ORD00020      T-Shirt  Clothing     32565.77              5
# 21   ORD00022        Jeans  Clothing     37129.73              3
# ..        ...          ...       ...          ...            ...
# 973  ORD00974      T-Shirt  Clothing      1434.23              2
# 983  ORD00984        Jeans  Clothing     22890.95              3
# 984  ORD00985        Jeans  Clothing     40905.69              5
# 987  ORD00988       Jacket  Clothing     46055.88              5
# 994  ORD00995     Sneakers  Clothing     11479.89              3
#
#      Total Sales (INR)  Order Date Payment Method  Customer Rating
# 1             51023.40  2024-12-18            UPI              3.9
# ...

# %%
df[(df['Category']=='Clothing') & (df['Quantity Sold']==4)]
# Out:
#      Order ID Product Name  Category  Price (INR)  Quantity Sold  \
# 1    ORD00002        Jeans  Clothing     12755.85              4
# 25   ORD00026      T-Shirt  Clothing      2053.11              4
# 26   ORD00027        Jeans  Clothing     38927.62              4
# 74   ORD00075     Sneakers  Clothing      1542.10              4
# 110  ORD00111       Jacket  Clothing     35811.10              4
# 114  ORD00115       Jacket  Clothing     26219.99              4
# 135  ORD00136       Jacket  Clothing     14043.16              4
# 202  ORD00203     Sneakers  Clothing     16468.59              4
# 217  ORD00218        Dress  Clothing     44241.68              4
# 250  ORD00251       Jacket  Clothing      1987.98              4
# 255  ORD00256       Jacket  Clothing     15068.72              4
# 279  ORD00280     Sneakers  Clothing     22968.18              4
# 307  ORD00308        Dress  Clothing     25379.68              4
# ...
